# %%
import pymongo

# %%
#client Mongo

client = pymongo.MongoClient("localhost", 27017)

# %%
#Database names

client.list_database_names()
# Out:
# ['admin',
#  'config',
#  'foodsales',
#  'local',
#  'shop',
#  'student_performance',
#  'titanic']

# %%
#Setting db as foodsales

db = client ["student_performance"]

# %%
#Listing out collection names

db.list_collection_names()
# Out:
# ['stu']

# %%
#Counting the no of documents

db.stu.count_documents({ })
# Out:
# 1000

# %%
#Finding one document using findone()

db.stu.find_one()
# Out:
# {'_id': ObjectId('61bac22a21d96a3979cf8d34'),
#  'gender': 'female',
#  'race/ethnicity': 'group D',
#  'parental level of education': "associate's degree",
#  'lunch': 'free/reduced',
#  'test preparation course': 'completed',
#  'math score': 75.0,
#  'reading score': 90.0,
#  'writing score': 88.0,
#  'Avg score': 84.0}

# %%
#Displaying the documents

for i in db.stu.find():
    print(i)
# Out:
# {'_id': ObjectId('61bac22a21d96a3979cf8d34'), 'gender': 'female', 'race/ethnicity': 'group D', 'parental level of education': "associate's degree", 'lunch': 'free/reduced', 'test preparation course': 'completed', 'math score': 75.0, 'reading score': 90.0, 'writing score': 88.0, 'Avg score': 84.0}
# {'_id': ObjectId('61bac22a21d96a3979cf8d35'), 'gender': 'female', 'race/ethnicity': 'group D', 'parental level of education': "associate's degree", 'lunch': 'free/reduced', 'test preparation course': 'completed', 'math score': 57.0, 'reading score': 74.0, 'writing score': 76.0, 'Avg score': 69.0}
# {'_id': ObjectId('61bac22a21d96a3979cf8d36'), 'gender': 'female', 'race/ethnicity': 'group D', 'parental level of education': "associate's degree", 'lunch': 'free/reduced', 'test preparation course': 'completed', 'math score': 77.0, 'reading score': 89.0, 'writing score': 98.0, 'Avg score': 88.0}
# ...

# %%
#Displaying the documents specified to gender(female)

for i in db.stu.find({'gender':'female'},{"_id":0,"race/ethnicity":1,"parental level of education":1,"lunch":1,"test preparation course":1,"gender":1,"math score":1,"reading score":1,"writing score":1,"average score":1}):
    print(i)
# Out:
# {'gender': 'female', 'race/ethnicity': 'group D', 'parental level of education': "associate's degree", 'lunch': 'free/reduced', 'test preparation course': 'completed', 'math score': 75.0, 'reading score': 90.0, 'writing score': 88.0}
# {'gender': 'female', 'race/ethnicity': 'group D', 'parental level of education': "associate's degree", 'lunch': 'free/reduced', 'test preparation course': 'completed', 'math score': 57.0, 'reading score': 74.0, 'writing score': 76.0}
# {'gender': 'female', 'race/ethnicity': 'group D', 'parental level of education': "associate's degree", 'lunch': 'free/reduced', 'test preparation course': 'completed', 'math score': 77.0, 'reading score': 89.0, 'writing score': 98.0}
# {'gender': 'female', 'race/ethnicity': 'group E', 'parental level of education': "associate's degree", 'lunch': 'free/reduced', 'test preparation course': 'completed', 'math score': 83.0, 'reading score': 86.0, 'writing score': 88.0}
# ...

# %%
#Displaying the documents specified to gender(male)

for i in db.stu.find({'gender':'male'},{"_id":0,"race/ethnicity":1,"parental level of education":1,"lunch":1,"test preparation course":1,"gender":1,"math score":1,"reading score":1,"writing score":1,"average score":1}):
    print(i)
# Out:
# {'gender': 'male', 'race/ethnicity': 'group E', 'parental level of education': "associate's degree", 'lunch': 'free/reduced', 'test preparation course': 'completed', 'math score': 77.0, 'reading score': 69.0, 'writing score': 68.0}
# {'gender': 'male', 'race/ethnicity': 'group C', 'parental level of education': "associate's degree", 'lunch': 'free/reduced', 'test preparation course': 'completed', 'math score': 43.0, 'reading score': 45.0, 'writing score': 50.0}
# {'gender': 'male', 'race/ethnicity': 'group C', 'parental level of education': "associate's degree", 'lunch': 'free/reduced', 'test preparation course': 'completed', 'math score': 78.0, 'reading score': 81.0, 'writing score': 82.0}
# {'gender': 'male', 'race/ethnicity': 'group E', 'parental level of education': "associate's degree", 'lunch': 'free/reduced', 'test preparation course': 'completed', 'math score': 100.0, 'reading score': 100.0, 'writing score': 93.0}
# ...

# %%
#Displaying the documents specified to group A:

for i in db.stu.find({'race/ethnicity':'group A'},{"_id":0,"race/ethnicity":1,"parental level of education":1,"lunch":1,"test preparation course":1,"gender":1,"math score":1,"reading score":1,"writing score":1,"average score":1}):
    print(i)
# Out:
# {'gender': 'male', 'race/ethnicity': 'group A', 'parental level of education': "associate's degree", 'lunch': 'free/reduced', 'test preparation course': 'completed', 'math score': 79.0, 'reading score': 82.0, 'writing score': 82.0}
# {'gender': 'male', 'race/ethnicity': 'group A', 'parental level of education': "associate's degree", 'lunch': 'free/reduced', 'test preparation course': 'completed', 'math score': 40.0, 'reading score': 55.0, 'writing score': 53.0}
# {'gender': 'male', 'race/ethnicity': 'group A', 'parental level of education': "bachelor's degree", 'lunch': 'free/reduced', 'test preparation course': 'completed', 'math score': 49.0, 'reading score': 58.0, 'writing score': 60.0}
# {'gender': 'female', 'race/ethnicity': 'group A', 'parental level of education': 'high school', 'lunch': 'free/reduced', 'test preparation course': 'completed', 'math score': 77.0, 'reading score': 88.0, 'writing score': 85.0}
# ...

# %%
#Displaying the documents specified to group B:

for i in db.stu.find({'race/ethnicity':'group B'},{"_id":0,"race/ethnicity":1,"parental level of education":1,"lunch":1,"test preparation course":1,"gender":1,"math score":1,"reading score":1,"writing score":1,"average score":1}):
    print(i)
# Out:
# {'gender': 'female', 'race/ethnicity': 'group B', 'parental level of education': "associate's degree", 'lunch': 'free/reduced', 'test preparation course': 'completed', 'math score': 76.0, 'reading score': 94.0, 'writing score': 87.0}
# {'gender': 'female', 'race/ethnicity': 'group B', 'parental level of education': "associate's degree", 'lunch': 'free/reduced', 'test preparation course': 'completed', 'math score': 68.0, 'reading score': 77.0, 'writing score': 80.0}
# {'gender': 'male', 'race/ethnicity': 'group B', 'parental level of education': "associate's degree", 'lunch': 'free/reduced', 'test preparation course': 'completed', 'math score': 82.0, 'reading score': 78.0, 'writing score': 74.0}
# {'gender': 'male', 'race/ethnicity': 'group B', 'parental level of education': "associate's degree", 'lunch': 'free/reduced', 'test preparation course': 'completed', 'math score': 69.0, 'reading score': 70.0, 'writing score': 63.0}
# ...

# %%
#Displaying the documents specified to group C:

for i in db.stu.find({'race/ethnicity':'group C'},{"_id":0,"race/ethnicity":1,"parental level of education":1,"lunch":1,"test preparation course":1,"gender":1,"math score":1,"reading score":1,"writing score":1,"average score":1}):
    print(i)
# Out:
# {'gender': 'female', 'race/ethnicity': 'group C', 'parental level of education': "associate's degree", 'lunch': 'free/reduced', 'test preparation course': 'completed', 'math score': 68.0, 'reading score': 67.0, 'writing score': 69.0}
# {'gender': 'female', 'race/ethnicity': 'group C', 'parental level of education': "associate's degree", 'lunch': 'free/reduced', 'test preparation course': 'completed', 'math score': 82.0, 'reading score': 93.0, 'writing score': 93.0}
# {'gender': 'female', 'race/ethnicity': 'group C', 'parental level of education': "associate's degree", 'lunch': 'free/reduced', 'test preparation course': 'completed', 'math score': 56.0, 'reading score': 68.0, 'writing score': 70.0}
# {'gender': 'male', 'race/ethnicity': 'group C', 'parental level of education': "associate's degree", 'lunch': 'free/reduced', 'test preparation course': 'completed', 'math score': 43.0, 'reading score': 45.0, 'writing score': 50.0}
# ...

# %%
#Displaying the documents specified to group D:

for i in db.stu.find({'race/ethnicity':'group D'},{"_id":0,"race/ethnicity":1,"parental level of education":1,"lunch":1,"test preparation course":1,"gender":1,"math score":1,"reading score":1,"writing score":1,"average score":1}):
    print(i)
# Out:
# {'gender': 'female', 'race/ethnicity': 'group D', 'parental level of education': "associate's degree", 'lunch': 'free/reduced', 'test preparation course': 'completed', 'math score': 75.0, 'reading score': 90.0, 'writing score': 88.0}
# {'gender': 'female', 'race/ethnicity': 'group D', 'parental level of education': "associate's degree", 'lunch': 'free/reduced', 'test preparation course': 'completed', 'math score': 57.0, 'reading score': 74.0, 'writing score': 76.0}
# {'gender': 'female', 'race/ethnicity': 'group D', 'parental level of education': "associate's degree", 'lunch': 'free/reduced', 'test preparation course': 'completed', 'math score': 77.0, 'reading score': 89.0, 'writing score': 98.0}
# {'gender': 'female', 'race/ethnicity': 'group D', 'parental level of education': "associate's degree", 'lunch': 'free/reduced', 'test preparation course': 'completed', 'math score': 74.0, 'reading score': 88.0, 'writing score': 90.0}
# ...

# %%
#Displaying the documents specified to group E:

for i in db.stu.find({'race/ethnicity':'group E'},{"_id":0,"race/ethnicity":1,"parental level of education":1,"lunch":1,"test preparation course":1,"gender":1,"math score":1,"reading score":1,"writing score":1,"average score":1}):
    print(i)
# Out:
# {'gender': 'female', 'race/ethnicity': 'group E', 'parental level of education': "associate's degree", 'lunch': 'free/reduced', 'test preparation course': 'completed', 'math score': 83.0, 'reading score': 86.0, 'writing score': 88.0}
# {'gender': 'female', 'race/ethnicity': 'group E', 'parental level of education': "associate's degree", 'lunch': 'free/reduced', 'test preparation course': 'completed', 'math score': 57.0, 'reading score': 68.0, 'writing score': 73.0}
# {'gender': 'male', 'race/ethnicity': 'group E', 'parental level of education': "associate's degree", 'lunch': 'free/reduced', 'test preparation course': 'completed', 'math score': 77.0, 'reading score': 69.0, 'writing score': 68.0}
# {'gender': 'male', 'race/ethnicity': 'group E', 'parental level of education': "associate's degree", 'lunch': 'free/reduced', 'test preparation course': 'completed', 'math score': 100.0, 'reading score': 100.0, 'writing score': 93.0}
# ...

# %%
#Displaying the documents specified to lunch(standard):

for i in db.stu.find({'lunch':'standard'},{"_id":0,"race/ethnicity":1,"parental level of education":1,"lunch":1,"test preparation course":1,"gender":1,"math score":1,"reading score":1,"writing score":1,"average score":1}):
    print(i)
# Out:
# {'gender': 'female', 'race/ethnicity': 'group A', 'parental level of education': "associate's degree", 'lunch': 'standard', 'test preparation course': 'completed', 'math score': 55.0, 'reading score': 65.0, 'writing score': 62.0}
# {'gender': 'female', 'race/ethnicity': 'group E', 'parental level of education': "associate's degree", 'lunch': 'standard', 'test preparation course': 'completed', 'math score': 82.0, 'reading score': 85.0, 'writing score': 86.0}
# {'gender': 'female', 'race/ethnicity': 'group B', 'parental level of education': "associate's degree", 'lunch': 'standard', 'test preparation course': 'completed', 'math score': 59.0, 'reading score': 70.0, 'writing score': 66.0}
# {'gender': 'female', 'race/ethnicity': 'group B', 'parental level of education': "associate's degree", 'lunch': 'standard', 'test preparation course': 'completed', 'math score': 61.0, 'reading score': 86.0, 'writing score': 87.0}
# ...

# %%
#Displaying the documents specified to lunch(free/reduced):

for i in db.stu.find({'lunch':'free/reduced'},{"_id":0,"race/ethnicity":1,"parental level of education":1,"lunch":1,"test preparation course":1,"gender":1,"math score":1,"reading score":1,"writing score":1,"average score":1}):
    print(i)
# Out:
# {'gender': 'female', 'race/ethnicity': 'group D', 'parental level of education': "associate's degree", 'lunch': 'free/reduced', 'test preparation course': 'completed', 'math score': 75.0, 'reading score': 90.0, 'writing score': 88.0}
# {'gender': 'female', 'race/ethnicity': 'group D', 'parental level of education': "associate's degree", 'lunch': 'free/reduced', 'test preparation course': 'completed', 'math score': 57.0, 'reading score': 74.0, 'writing score': 76.0}
# {'gender': 'female', 'race/ethnicity': 'group D', 'parental level of education': "associate's degree", 'lunch': 'free/reduced', 'test preparation course': 'completed', 'math score': 77.0, 'reading score': 89.0, 'writing score': 98.0}
# {'gender': 'female', 'race/ethnicity': 'group E', 'parental level of education': "associate's degree", 'lunch': 'free/reduced', 'test preparation course': 'completed', 'math score': 83.0, 'reading score': 86.0, 'writing score': 88.0}
# ...

# %%
#Displaying the documents specified to test preparation course(completed):

for i in db.stu.find({'test preparation course':'completed'},{"_id":0,"race/ethnicity":1,"parental level of education":1,"lunch":1,"test preparation course":1,"gender":1,"math score":1,"reading score":1,"writing score":1,"average score":1}):
    print(i)
# Out:
# {'gender': 'female', 'race/ethnicity': 'group D', 'parental level of education': "associate's degree", 'lunch': 'free/reduced', 'test preparation course': 'completed', 'math score': 75.0, 'reading score': 90.0, 'writing score': 88.0}
# {'gender': 'female', 'race/ethnicity': 'group D', 'parental level of education': "associate's degree", 'lunch': 'free/reduced', 'test preparation course': 'completed', 'math score': 57.0, 'reading score': 74.0, 'writing score': 76.0}
# {'gender': 'female', 'race/ethnicity': 'group D', 'parental level of education': "associate's degree", 'lunch': 'free/reduced', 'test preparation course': 'completed', 'math score': 77.0, 'reading score': 89.0, 'writing score': 98.0}
# {'gender': 'female', 'race/ethnicity': 'group E', 'parental level of education': "associate's degree", 'lunch': 'free/reduced', 'test preparation course': 'completed', 'math score': 83.0, 'reading score': 86.0, 'writing score': 88.0}
# ...

# %%
#Displaying the documents specified to test preparation course(none):

for i in db.stu.find({'test preparation course':'none'},{"_id":0,"race/ethnicity":1,"parental level of education":1,"lunch":1,"test preparation course":1,"gender":1,"math score":1,"reading score":1,"writing score":1,"average score":1}):
    print(i)
# Out:
# {'gender': 'female', 'race/ethnicity': 'group C', 'parental level of education': "associate's degree", 'lunch': 'free/reduced', 'test preparation course': 'none', 'math score': 54.0, 'reading score': 58.0, 'writing score': 61.0}
# {'gender': 'female', 'race/ethnicity': 'group E', 'parental level of education': "associate's degree", 'lunch': 'free/reduced', 'test preparation course': 'none', 'math score': 50.0, 'reading score': 56.0, 'writing score': 54.0}
# {'gender': 'female', 'race/ethnicity': 'group A', 'parental level of education': "associate's degree", 'lunch': 'free/reduced', 'test preparation course': 'none', 'math score': 41.0, 'reading score': 51.0, 'writing score': 48.0}
# {'gender': 'female', 'race/ethnicity': 'group B', 'parental level of education': "associate's degree", 'lunch': 'free/reduced', 'test preparation course': 'none', 'math score': 52.0, 'reading score': 76.0, 'writing score': 70.0}
# ...

# %%
#Displaying top 5 average score

x = db.abc.find({},{"_id":0,'gender':1}).sort("Avg score", 1).limit(5)

for i in x:
    print(i)
